# %%
# tuple()
# it is like list BUT can't change - It is immutable
# faster than list
# also ordered and allows duplciate

# %%
tuple1 = (10,20,30,40,50)
tuple2 = (50,60,70,80,90)
print(tuple1[0])
print(tuple1[-1])
print(tuple1[:])
print(tuple1[::2])
print(tuple1[::-1])
tuple3 = tuple1+tuple2
print(tuple1+tuple2)
print(tuple3)

print(len(tuple2))
print(tuple3.count(50))
print(min(tuple3))
print(max(tuple3))
print(sum(tuple3))
tuple4 = (10,20,30,0)
print(all(tuple4))
tuple5 = (0,False,None,"")
print(any(tuple5))
tuple6 = (0,False,None,"",[0])
print(any(tuple6))
tuple7 = (0,False,None,"",[None])
print(any(tuple7))
# Out:
# 10
# 50
# (10, 20, 30, 40, 50)
# (10, 30, 50)
# (50, 40, 30, 20, 10)
# (10, 20, 30, 40, 50, 50, 60, 70, 80, 90)
# (10, 20, 30, 40, 50, 50, 60, 70, 80, 90)
# 5
# 2
# 10
# 90
# 500
# False
# False
# True
# True

# %%
tuple5 = (10, 100, 1000, 10000)
print(tuple5)

# %%
tuple8 = 10
print(tuple8)
print(type(tuple8))
tuple8 = (10)
print(tuple8)
print(type(tuple8))
tuple8 = ("vivek")
print(tuple8)
print(type(tuple8))

tuple8 = (10,)
print(tuple8)
print(type(tuple8))
tuple8 = ("vivek",)
print(tuple8)
print(type(tuple8))
# Out:
# 10
# <class 'int'>
# 10
# <class 'int'>
# vivek
# <class 'str'>
# (10,)
# <class 'tuple'>
# ('vivek',)
# <class 'tuple'>

# %%
tuple1 = (10,20,30,40,50,50,60,70,80,90)
print(tuple1)
list1 = list(tuple1)
print(type(list1))
print(list1)
list1.remove(50)
# print(list1)
tuple2 = tuple(list1)
print(tuple2)
# Out:
# (10, 20, 30, 40, 50, 50, 60, 70, 80, 90)
# <class 'list'>
# [10, 20, 30, 40, 50, 50, 60, 70, 80, 90]
# (10, 20, 30, 40, 50, 60, 70, 80, 90)

# %%
var = "10"
print(type(var))
var = int(var)
print(type(var))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# sets{}
# it is inbuild data structure and it does not allow duplciates
# it is unordered
# it is mutable

# %%
tuple1 = (10,20,30,40,50,50,60,70,80,90)
print(tuple1)
set1 = set(tuple1)
print(set1)

set1.add(100)
print(set1)
set1.remove(50)
print(set1)
set2 = {100,200,300}
set3 = {300,400,500}
set4 = set2 | set3 # AUB 
print("AUB A|B: ",set4)
# AUB 
# ANB
# A-B
set4 = set2 & set3
print("ANB A&B:",set4)
set4 = set2 - set3
print("A-B A-B:",set4)
# print(set4)

list1 = [10,20,30,40,50]
list2 = [50,60,70,80,90]
list3 = list1+list2
print(list3)
print(list3.count(50))
# Out:
# (10, 20, 30, 40, 50, 50, 60, 70, 80, 90)
# {70, 40, 10, 80, 50, 20, 90, 60, 30}
# {100, 70, 40, 10, 80, 50, 20, 90, 60, 30}
# {100, 70, 40, 10, 80, 20, 90, 60, 30}
# AUB A|B:  {400, 100, 500, 200, 300}
# ANB A&B: {300}
# A-B A-B: {200, 100}
